# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/glioma-mcd-2025/Data_122824/Submission_template.csv
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1370.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0967.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0896.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0991.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0735.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0676.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0325.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1027.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1394.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0855.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0711.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1286.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0458.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0050.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0628.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0508.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1437.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0355.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0620.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0931.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0575.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0394.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0659.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0556.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0657.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0044.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0327.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0944.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0352.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0397.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0265.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1226.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0108.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0942.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0005.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0781.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0109.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0701.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0554.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0231.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1173.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0081.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1401.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0556.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1300.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0354.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1363.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0045.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1228.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0886.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1064.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0924.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0091.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1284.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0375.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0417.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0880.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0181.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1126.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1265.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1088.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0623.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1040.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1062.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1293.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0306.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0279.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0082.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1399.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0800.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0820.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0882.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0202.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1007.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0579.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0810.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0898.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0760.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1431.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0830.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0197.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0957.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1058.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0664.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0867.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0833.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0734.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0230.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0542.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0890.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1015.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1205.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1312.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0276.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0170.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0748.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1389.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1109.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0027.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0494.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0805.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0618.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1387.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0293.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0076.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0359.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1236.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0233.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0414.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0656.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0930.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0439.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1267.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1036.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0787.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0586.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0444.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0982.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0251.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1420.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0939.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0493.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0385.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0476.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0679.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0976.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0667.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0896.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0068.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0909.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0320.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1153.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1352.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1238.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0191.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0397.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0280.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0508.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0686.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0710.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1193.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1131.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0747.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0574.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0520.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0146.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1266.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0155.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0564.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0163.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1169.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1249.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0535.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0388.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0187.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0411.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0530.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0861.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0051.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0225.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0749.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0704.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0270.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1099.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0238.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1097.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0642.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1215.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0203.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0763.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1351.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0403.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1226.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0399.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0966.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1255.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0917.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1213.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1152.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0069.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1294.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0970.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0897.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0214.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0529.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1198.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0770.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0868.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0032.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1069.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0733.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0895.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1170.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0935.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1019.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0005.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0521.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0980.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1049.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1334.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1020.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1086.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0672.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1046.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0921.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0553.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0725.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1327.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0206.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1178.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0849.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0405.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1272.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1337.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1178.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0797.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1039.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0928.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0440.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0106.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0308.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0061.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1284.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0701.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0904.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0157.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0031.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0794.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0571.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0935.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0840.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0877.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1019.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0481.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0059.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0247.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1006.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0813.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0773.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0565.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0956.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0207.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0774.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0294.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1083.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0347.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0395.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0436.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0784.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0338.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1013.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0013.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0823.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0619.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0215.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0737.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0581.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0080.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0330.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0067.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0980.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1268.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0320.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1242.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0805.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0539.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0141.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0250.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1130.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0607.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1311.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0597.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1157.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1394.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0858.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0615.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0024.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0821.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0770.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0815.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1173.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0168.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1068.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0645.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0050.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0286.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0235.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0927.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0863.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0878.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1293.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1435.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1151.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1147.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0176.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1049.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0757.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0101.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1338.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0814.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0400.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0444.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0429.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0109.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1305.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0895.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0644.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1374.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1177.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0441.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0917.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1406.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0833.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0311.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1354.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1186.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0171.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0149.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0752.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0549.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1438.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0933.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0205.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0075.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0717.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0173.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0312.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0891.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0199.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1189.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0532.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1249.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0022.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1243.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1379.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0820.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1222.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1402.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0291.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0415.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0998.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0739.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0241.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0528.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0351.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0550.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0809.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1285.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1315.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0024.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0111.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1303.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0208.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0324.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1408.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1308.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0063.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0703.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0095.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0600.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0042.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1430.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1317.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0001.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0549.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0294.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0700.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0661.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0177.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1360.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0264.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0482.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0795.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0314.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0740.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0755.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0204.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0230.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0087.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0568.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1319.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0138.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1278.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0915.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0339.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0412.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1256.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0707.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0655.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1137.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0263.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0812.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0362.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0338.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1344.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0867.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1386.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1252.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0730.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0846.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0842.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0941.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0421.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0169.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0186.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1217.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0574.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0105.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0164.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0485.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0504.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0432.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0954.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0098.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1121.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0325.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1283.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1297.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1407.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1074.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0108.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0432.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0719.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1066.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1306.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0823.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0301.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0345.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0931.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0952.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0319.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1038.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0911.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0131.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0801.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1114.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0126.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0892.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0578.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0937.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1154.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1412.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1357.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0846.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0125.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0460.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0084.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0786.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0415.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0642.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0905.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1375.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0211.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1231.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0464.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1167.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1094.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0836.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0914.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1014.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1359.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0499.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0136.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1355.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0713.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0443.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0700.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1359.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1316.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0543.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0968.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0622.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0921.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0203.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0013.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0501.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0392.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0779.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0349.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0853.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0839.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0630.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0213.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0806.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0262.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1001.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0884.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0163.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0064.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0666.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1030.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0727.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0319.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0346.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1085.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1098.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0585.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1024.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0486.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1369.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0678.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1304.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0913.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1191.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1057.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1334.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0599.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0092.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0746.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0656.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0687.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0281.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0451.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1241.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0601.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0724.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1369.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0269.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0152.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0357.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0573.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1199.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0606.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0278.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0185.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0696.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1069.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0993.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0901.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0821.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1131.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0429.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0796.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1302.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1061.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1031.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0329.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0145.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0694.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1375.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0210.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0876.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0353.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1314.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0605.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1001.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0963.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1234.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1192.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0076.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0489.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0350.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0526.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0601.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0680.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0570.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1280.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0650.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1386.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1350.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0941.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1052.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0925.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0107.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0781.jpg
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training0905.json
# /kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training/training1362.jpg
# ...
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0009.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0196.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0191.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0029.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0020.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0176.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0013.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0050.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0088.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0084.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0036.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0152.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0194.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0155.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0188.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0178.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0060.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0128.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0138.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0054.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0200.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0012.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0130.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0161.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0197.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0014.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0021.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0100.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0056.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0083.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0114.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0124.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0052.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0079.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0003.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0077.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0186.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0146.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0190.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0055.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0033.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0154.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0034.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0010.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0087.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0018.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0066.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0091.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0106.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0069.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0117.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0159.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0171.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0184.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0065.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0200.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0164.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0098.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0081.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0016.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0151.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0075.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0025.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0122.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0035.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0100.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0068.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0071.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0136.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0015.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0182.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0003.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0005.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0092.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0054.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0001.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0028.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0143.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0198.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0065.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0181.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0140.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0045.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0026.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0011.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0081.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0123.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0161.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0129.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0137.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0014.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0193.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0031.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0122.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0009.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0165.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0049.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0189.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0187.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0096.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0166.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0183.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0086.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0133.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0168.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0142.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0035.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0159.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0152.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0067.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0027.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0088.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0193.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0016.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0154.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0181.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0127.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0180.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0109.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0157.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0073.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0150.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0068.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0072.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0101.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0108.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0015.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0059.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0180.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0121.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0148.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0141.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0119.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0039.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0110.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0007.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0055.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0006.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0033.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0094.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0041.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0075.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0092.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0191.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0189.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0107.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0163.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0057.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0064.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0126.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0095.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0141.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0149.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0134.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0106.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0027.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0103.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0125.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0130.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0036.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0101.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0110.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0044.jpg
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0048.json
# /kaggle/input/glioma-mcd-2025/archive/Glioma_MDC_2025_test/Glioma_MDC_2025_test/testing0199.jpg

# %%
import torch
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import copy
import os
import json

from torch import nn, optim
from torch.utils.data import DataLoader, Subset, random_split
from torchvision import datasets, models, transforms
from torchvision.datasets import ImageFolder
from torchsummary import summary
from collections import Counter
from PIL import Image

from sklearn.model_selection import train_test_split, StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    matthews_corrcoef,
    roc_auc_score,
    precision_recall_curve,
    auc,
    confusion_matrix,
)

# %%
# Define the dataset folder
data_folder = '/kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_training'

# %%
json_files = sorted([f for f in os.listdir(data_folder) if f.endswith(".json")])

data = []

# Counting mitosis and non-mitosis regions per image using JSONs
for json_file in json_files:
    image_name = json_file.replace(".json", ".jpg")
    with open(os.path.join(data_folder, json_file), "r") as f:
        json_data = json.load(f)
    
    mitosis_count = sum(1 for shape in json_data["shapes"] if shape["label"] == "Mitosis")
    non_mitosis_count = sum(1 for shape in json_data["shapes"] if shape["label"] == "Non-mitosis")
    
    if mitosis_count > 0 and non_mitosis_count > 0:
        category = "mixed"
    elif mitosis_count > 0:
        category = "mitosis"
    else:
        category = "non-mitosis"
    
    data.append([image_name, json_file, mitosis_count, non_mitosis_count, category])

df = pd.DataFrame(data, columns=["image", "json", "mitosis_count", "non_mitosis_count", "category"])

# %%
# Stratified split to avoid biases from labels
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(splitter.split(df, df["category"]))

train_df = df.iloc[train_idx]
val_df = df.iloc[val_idx]

# %%
# Image transformations for train 
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=30),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class MitosisDataset(Dataset):
    def __init__(self, dataframe, data_folder, transform=None):
        self.dataframe = dataframe
        self.data_folder = data_folder
        self.transform = transform
    
    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        image_path = os.path.join(self.data_folder, row['image'])
        json_path = os.path.join(self.data_folder, row['json'])
    
        image = Image.open(image_path).convert("RGB")
        with open(json_path, 'r') as f:
            json_data = json.load(f)
    
        rois = []
        labels = []
    
        for shape in json_data["shapes"]:
            points = shape["points"]
            label = 1 if shape["label"] == "Mitosis" else 0
        
            x_min = int(min(p[0] for p in points))
            y_min = int(min(p[1] for p in points))
            x_max = int(max(p[0] for p in points))
            y_max = int(max(p[1] for p in points))
        
            roi = image.crop((x_min, y_min, x_max, y_max))
            if self.transform:
                roi = self.transform(roi)
        
            rois.append(roi)
            labels.append(label)
    
        return rois, labels

# %%
def collate_fn(batch):
    all_rois = []
    all_labels = []
    
    for rois, labels in batch:
        all_rois.extend(rois)
        all_labels.extend(labels)
    
    all_rois = torch.stack(all_rois)  # ROIs to a tensor
    all_labels = torch.tensor(all_labels, dtype=torch.long)  # labels to a tensor
    
    return all_rois, all_labels

# %%
train_dataset = MitosisDataset(train_df, data_folder, transform)
val_dataset = MitosisDataset(val_df, data_folder, transform)

# %%
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torch.nn as nn
import torchvision.models as models

# the best model that worked for me, I tried several other model architectures e.g. DenseNet, InceptionNet, ResNet, etc. 

vgg19 = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1) 

# Freeze all pretrained layers except the classifier (fully connected layers)
for param in vgg19.features.parameters():
    param.requires_grad = False

# Unfreeze the classifier layers
for param in vgg19.classifier.parameters():
    param.requires_grad = True

# %%
print(vgg19) # vgg19 architecture
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
vgg19.classifier = nn.Sequential(
    nn.Linear(25088, 2048),  
    nn.BatchNorm1d(2048),
    nn.GELU(),
    nn.Dropout(0.1),

    nn.Linear(2048, 1024),
    nn.BatchNorm1d(1024),
    nn.GELU(),
    nn.Dropout(0.1),

    nn.Linear(1024, 512),
    nn.BatchNorm1d(512),
    nn.GELU(),
    nn.Dropout(0.1),

    nn.Linear(512, 1)
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vgg19 = vgg19.to(device)

# %%
import torch.optim.lr_scheduler as lr_scheduler

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(vgg19.parameters(), lr=0.001)

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.9, patience=2, verbose=True)

# %%
def evaluate_metrics(y_true, y_pred, y_prob):
    metrics = {}
    metrics['accuracy'] = accuracy_score(y_true, y_pred)
    metrics['balanced_accuracy'] = balanced_accuracy_score(y_true, y_pred)
    metrics['f1_score'] = f1_score(y_true, y_pred)  
    metrics['mcc'] = matthews_corrcoef(y_true, y_pred)
    metrics['roc_auc'] = roc_auc_score(y_true, y_prob)  

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    
    sensitivity = tp / (tp + fn)  
    specificity = tn / (tn + fp)  

  
    metrics['sensitivity'] = sensitivity
    metrics['specificity'] = specificity

    metrics_str = (f"Accuracy: {metrics['accuracy']:.4f}, "
                   f"Balanced Accuracy: {metrics['balanced_accuracy']:.4f}, "
                   f"F1 Score: {metrics['f1_score']:.4f}, "
                   f"MCC: {metrics['mcc']:.4f}, "
                   f"ROC AUC: {metrics['roc_auc']:.4f}, "
                   f"Sensitivity: {metrics['sensitivity']:.4f}, "
                   f"Specificity: {metrics['specificity']:.4f}")
    
    return metrics, metrics_str

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    y_true, y_pred, y_prob = [], [], []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)  

        optimizer.zero_grad()
        outputs = model(images).squeeze(1)  # raw logits

        # Compute loss
        loss = criterion(outputs, labels.squeeze(1))  
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Convert logits to probabilities
        probs = torch.sigmoid(outputs)  
        preds = (probs >= 0.5).long()  # Threshold at 0.5 for class predictions (0 or 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())
        y_prob.extend(probs.detach().cpu().numpy())

    avg_loss = running_loss / len(train_loader)
    metrics, metrics_str = evaluate_metrics(y_true, y_pred, y_prob)
    return avg_loss, (metrics, metrics_str)

# %%
def evaluate_model(model, val_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    y_true, y_pred, y_prob = [], [], []

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device).float().unsqueeze(1)  
            outputs = model(images).squeeze(1)  

            
            loss = criterion(outputs, labels.squeeze(1))  
            running_loss += loss.item()

            probs = torch.sigmoid(outputs)
            preds = (probs >= 0.5).long()  
            
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
            y_prob.extend(probs.cpu().numpy())

    avg_loss = running_loss / len(val_loader)
    metrics, metrics_str = evaluate_metrics(y_true, y_pred, y_prob)
    return avg_loss, (metrics, metrics_str)

# %%
# Training and validation loop
num_epochs = 20
best_f1 = 0.0
best_model_wts = copy.deepcopy(vgg19.state_dict())

for epoch in range(num_epochs):
    # Train for one epoch
    train_loss, (train_metrics, train_metrics_str) = train(vgg19, train_loader, criterion, optimizer, device)
    
    # Validate after each epoch
    val_loss, (val_metrics, val_metrics_str) = evaluate_model(vgg19, val_loader, criterion, device)

    scheduler.step(val_loss)  # Adjusting learning rate based on validation loss
    
    # Saving the best model based on validation F1 score
    if val_metrics['f1_score'] > best_f1:
        best_f1 = val_metrics['f1_score']
        best_model_wts = copy.deepcopy(vgg19.state_dict())

    current_lr = optimizer.param_groups[0]['lr']
    print(f"Epoch: {epoch + 1}/{num_epochs} -------------------------------------------------------------------------------")
    print(f"Train Loss: {train_loss:.4f}, Train Metrics: {train_metrics_str}")
    print(f"Val Loss: {val_loss:.4f}, Val Metrics: {val_metrics_str}")
    print(f"Learning Rate: {current_lr:.6f}")

# Saving the best model
vgg19.load_state_dict(best_model_wts)
torch.save(vgg19.state_dict(), "mcd_vgg19_0408_b32.pth")
print(f"Best model saved with best Score: {best_f1}")
# Out:
# Epoch: 1/20 -------------------------------------------------------------------------------
# Train Loss: 0.3908, Train Metrics: Accuracy: 0.8327, Balanced Accuracy: 0.8315, F1 Score: 0.8472, MCC: 0.6623, ROC AUC: 0.9049, Sensitivity: 0.8437, Specificity: 0.8193
# Val Loss: 0.2486, Val Metrics: Accuracy: 0.8954, Balanced Accuracy: 0.8937, F1 Score: 0.9056, MCC: 0.7884, ROC AUC: 0.9615, Sensitivity: 0.9106, Specificity: 0.8767
# Learning Rate: 0.001000
# Epoch: 2/20 -------------------------------------------------------------------------------
# Train Loss: 0.2566, Train Metrics: Accuracy: 0.9009, Balanced Accuracy: 0.9027, F1 Score: 0.9075, MCC: 0.8021, ROC AUC: 0.9569, Sensitivity: 0.8845, Specificity: 0.9208
# Val Loss: 0.2659, Val Metrics: Accuracy: 0.8892, Balanced Accuracy: 0.8906, F1 Score: 0.8971, MCC: 0.7782, ROC AUC: 0.9562, Sensitivity: 0.8771, Specificity: 0.9041
# Learning Rate: 0.001000
# Epoch: 3/20 -------------------------------------------------------------------------------
# Train Loss: 0.2343, Train Metrics: Accuracy: 0.9086, Balanced Accuracy: 0.9114, F1 Score: 0.9140, MCC: 0.8190, ROC AUC: 0.9643, Sensitivity: 0.8831, Specificity: 0.9398
# Val Loss: 0.3070, Val Metrics: Accuracy: 0.8738, Balanced Accuracy: 0.8703, F1 Score: 0.8877, MCC: 0.7446, ROC AUC: 0.9514, Sensitivity: 0.9050, Specificity: 0.8356
# Learning Rate: 0.001000
# Epoch: 4/20 -------------------------------------------------------------------------------
# Train Loss: 0.2354, Train Metrics: Accuracy: 0.9070, Balanced Accuracy: 0.9091, F1 Score: 0.9132, MCC: 0.8148, ROC AUC: 0.9647, Sensitivity: 0.8887, Specificity: 0.9294
# Val Loss: 0.2167, Val Metrics: Accuracy: 0.9015, Balanced Accuracy: 0.9049, F1 Score: 0.9070, MCC: 0.8058, ROC AUC: 0.9706, Sensitivity: 0.8715, Specificity: 0.9384
# Learning Rate: 0.001000
# Epoch: 5/20 -------------------------------------------------------------------------------
# Train Loss: 0.1886, Train Metrics: Accuracy: 0.9132, Balanced Accuracy: 0.9144, F1 Score: 0.9197, MCC: 0.8261, ROC AUC: 0.9764, Sensitivity: 0.9028, Specificity: 0.9260
# Val Loss: 0.2587, Val Metrics: Accuracy: 0.9015, Balanced Accuracy: 0.9037, F1 Score: 0.9080, MCC: 0.8038, ROC AUC: 0.9590, Sensitivity: 0.8827, Specificity: 0.9247
# Learning Rate: 0.001000
# Epoch: 6/20 -------------------------------------------------------------------------------
# Train Loss: 0.2084, Train Metrics: Accuracy: 0.9179, Balanced Accuracy: 0.9193, F1 Score: 0.9239, MCC: 0.8356, ROC AUC: 0.9715, Sensitivity: 0.9056, Specificity: 0.9329
# Val Loss: 0.2258, Val Metrics: Accuracy: 0.9200, Balanced Accuracy: 0.9211, F1 Score: 0.9261, MCC: 0.8395, ROC AUC: 0.9683, Sensitivity: 0.9106, Specificity: 0.9315
# Learning Rate: 0.001000
# Epoch: 7/20 -------------------------------------------------------------------------------
# Train Loss: 0.1935, Train Metrics: Accuracy: 0.9163, Balanced Accuracy: 0.9193, F1 Score: 0.9213, MCC: 0.8346, ROC AUC: 0.9753, Sensitivity: 0.8901, Specificity: 0.9484
# Val Loss: 0.1966, Val Metrics: Accuracy: 0.9077, Balanced Accuracy: 0.9074, F1 Score: 0.9157, MCC: 0.8138, ROC AUC: 0.9787, Sensitivity: 0.9106, Specificity: 0.9041
# Learning Rate: 0.001000
# Epoch: 8/20 -------------------------------------------------------------------------------
# Train Loss: 0.1977, Train Metrics: Accuracy: 0.9241, Balanced Accuracy: 0.9268, F1 Score: 0.9288, MCC: 0.8497, ROC AUC: 0.9729, Sensitivity: 0.9000, Specificity: 0.9535
# Val Loss: 0.2552, Val Metrics: Accuracy: 0.8892, Balanced Accuracy: 0.8900, F1 Score: 0.8977, MCC: 0.7775, ROC AUC: 0.9609, Sensitivity: 0.8827, Specificity: 0.8973
# Learning Rate: 0.001000
# Epoch: 9/20 -------------------------------------------------------------------------------
# Train Loss: 0.1810, Train Metrics: Accuracy: 0.9311, Balanced Accuracy: 0.9331, F1 Score: 0.9357, MCC: 0.8628, ROC AUC: 0.9786, Sensitivity: 0.9127, Specificity: 0.9535
# Val Loss: 0.2318, Val Metrics: Accuracy: 0.9108, Balanced Accuracy: 0.9139, F1 Score: 0.9159, MCC: 0.8238, ROC AUC: 0.9637, Sensitivity: 0.8827, Specificity: 0.9452
# Learning Rate: 0.001000
# Epoch: 10/20 -------------------------------------------------------------------------------
# Train Loss: 0.1799, Train Metrics: Accuracy: 0.9272, Balanced Accuracy: 0.9302, F1 Score: 0.9315, MCC: 0.8564, ROC AUC: 0.9782, Sensitivity: 0.9000, Specificity: 0.9604
# Val Loss: 0.2014, Val Metrics: Accuracy: 0.9108, Balanced Accuracy: 0.9165, F1 Score: 0.9139, MCC: 0.8290, ROC AUC: 0.9743, Sensitivity: 0.8603, Specificity: 0.9726
# Learning Rate: 0.000900
# Epoch: 11/20 -------------------------------------------------------------------------------
# Train Loss: 0.1762, Train Metrics: Accuracy: 0.9256, Balanced Accuracy: 0.9277, F1 Score: 0.9306, MCC: 0.8520, ROC AUC: 0.9777, Sensitivity: 0.9070, Specificity: 0.9484
# Val Loss: 0.2148, Val Metrics: Accuracy: 0.9046, Balanced Accuracy: 0.9077, F1 Score: 0.9101, MCC: 0.8114, ROC AUC: 0.9697, Sensitivity: 0.8771, Specificity: 0.9384
# Learning Rate: 0.000900
# Epoch: 12/20 -------------------------------------------------------------------------------
# Train Loss: 0.1740, Train Metrics: Accuracy: 0.9318, Balanced Accuracy: 0.9352, F1 Score: 0.9357, MCC: 0.8662, ROC AUC: 0.9789, Sensitivity: 0.9014, Specificity: 0.9690
# Val Loss: 0.2094, Val Metrics: Accuracy: 0.9046, Balanced Accuracy: 0.9027, F1 Score: 0.9141, MCC: 0.8070, ROC AUC: 0.9747, Sensitivity: 0.9218, Specificity: 0.8836
# Learning Rate: 0.000900
# Epoch: 13/20 -------------------------------------------------------------------------------
# Train Loss: 0.2101, Train Metrics: Accuracy: 0.9171, Balanced Accuracy: 0.9195, F1 Score: 0.9224, MCC: 0.8353, ROC AUC: 0.9706, Sensitivity: 0.8958, Specificity: 0.9432
# Val Loss: 0.1894, Val Metrics: Accuracy: 0.9200, Balanced Accuracy: 0.9211, F1 Score: 0.9261, MCC: 0.8395, ROC AUC: 0.9771, Sensitivity: 0.9106, Specificity: 0.9315
# Learning Rate: 0.000900
# Epoch: 14/20 -------------------------------------------------------------------------------
# Train Loss: 0.1910, Train Metrics: Accuracy: 0.9249, Balanced Accuracy: 0.9281, F1 Score: 0.9291, MCC: 0.8521, ROC AUC: 0.9746, Sensitivity: 0.8958, Specificity: 0.9604
# Val Loss: 0.2696, Val Metrics: Accuracy: 0.9046, Balanced Accuracy: 0.9046, F1 Score: 0.9127, MCC: 0.8077, ROC AUC: 0.9586, Sensitivity: 0.9050, Specificity: 0.9041
# Learning Rate: 0.000900
# Epoch: 15/20 -------------------------------------------------------------------------------
# Train Loss: 0.1777, Train Metrics: Accuracy: 0.9287, Balanced Accuracy: 0.9313, F1 Score: 0.9332, MCC: 0.8588, ROC AUC: 0.9789, Sensitivity: 0.9056, Specificity: 0.9570
# Val Loss: 0.2139, Val Metrics: Accuracy: 0.9108, Balanced Accuracy: 0.9127, F1 Score: 0.9169, MCC: 0.8220, ROC AUC: 0.9676, Sensitivity: 0.8939, Specificity: 0.9315
# Learning Rate: 0.000900
# Epoch: 16/20 -------------------------------------------------------------------------------
# Train Loss: 0.1651, Train Metrics: Accuracy: 0.9311, Balanced Accuracy: 0.9334, F1 Score: 0.9356, MCC: 0.8632, ROC AUC: 0.9809, Sensitivity: 0.9099, Specificity: 0.9570
# Val Loss: 0.2418, Val Metrics: Accuracy: 0.9046, Balanced Accuracy: 0.9052, F1 Score: 0.9122, MCC: 0.8082, ROC AUC: 0.9645, Sensitivity: 0.8994, Specificity: 0.9110
# Learning Rate: 0.000810
# Epoch: 17/20 -------------------------------------------------------------------------------
# Train Loss: 0.1526, Train Metrics: Accuracy: 0.9326, Balanced Accuracy: 0.9359, F1 Score: 0.9364, MCC: 0.8677, ROC AUC: 0.9832, Sensitivity: 0.9028, Specificity: 0.9690
# Val Loss: 0.2081, Val Metrics: Accuracy: 0.9108, Balanced Accuracy: 0.9120, F1 Score: 0.9174, MCC: 0.8212, ROC AUC: 0.9704, Sensitivity: 0.8994, Specificity: 0.9247
# Learning Rate: 0.000810
# Epoch: 18/20 -------------------------------------------------------------------------------
# Train Loss: 0.1615, Train Metrics: Accuracy: 0.9295, Balanced Accuracy: 0.9323, F1 Score: 0.9338, MCC: 0.8607, ROC AUC: 0.9800, Sensitivity: 0.9042, Specificity: 0.9604
# Val Loss: 0.2378, Val Metrics: Accuracy: 0.9108, Balanced Accuracy: 0.9120, F1 Score: 0.9174, MCC: 0.8212, ROC AUC: 0.9627, Sensitivity: 0.8994, Specificity: 0.9247
# Learning Rate: 0.000810
# Epoch: 19/20 -------------------------------------------------------------------------------
# Train Loss: 0.1429, Train Metrics: Accuracy: 0.9396, Balanced Accuracy: 0.9426, F1 Score: 0.9432, MCC: 0.8811, ROC AUC: 0.9851, Sensitivity: 0.9127, Specificity: 0.9725
# Val Loss: 0.1900, Val Metrics: Accuracy: 0.9323, Balanced Accuracy: 0.9348, F1 Score: 0.9368, MCC: 0.8657, ROC AUC: 0.9748, Sensitivity: 0.9106, Specificity: 0.9589
# Learning Rate: 0.000729
# Epoch: 20/20 -------------------------------------------------------------------------------
# Train Loss: 0.1446, Train Metrics: Accuracy: 0.9396, Balanced Accuracy: 0.9424, F1 Score: 0.9433, MCC: 0.8808, ROC AUC: 0.9846, Sensitivity: 0.9141, Specificity: 0.9707
# Val Loss: 0.2262, Val Metrics: Accuracy: 0.9077, Balanced Accuracy: 0.9080, F1 Score: 0.9153, MCC: 0.8142, ROC AUC: 0.9738, Sensitivity: 0.9050, Specificity: 0.9110
# Learning Rate: 0.000729
# Best model saved with best Score: 0.9367816091954023

# %%
vgg19.load_state_dict(torch.load("mcd_vgg19_0408_b32.pth", map_location=device))
vgg19.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=2048, bias=True)
#     (1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): GELU(approximate='none')
#     (7): Dropout(p=0.1, inplace=False)
#     (8): Linear(in_features=1024, out_features=512, bias=True)
#     (9): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): GELU(approximate='none')
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %%
test_folder = '/kaggle/input/glioma-mcd-2025/Data_122824/Glioma_MDC_2025_test'

# %%
val_loss, (val_metrics, val_metrics_str) = evaluate_model(vgg19, val_loader, criterion, device)
val_metrics_str
# Out:
# 'Accuracy: 0.9262, Balanced Accuracy: 0.9273, F1 Score: 0.9318, MCC: 0.8519, ROC AUC: 0.9717, Sensitivity: 0.9162, Specificity: 0.9384'

# %%
class TestMitosisDataset(Dataset):
    def __init__(self, test_folder, transform=None):
        self.test_folder = test_folder
        self.transform = transform

        # Get all JSON files
        self.json_files = sorted([f for f in os.listdir(test_folder) if f.endswith(".json")])
    
    def __len__(self):
        return len(self.json_files)

    def __getitem__(self, idx):
        json_file = self.json_files[idx]
        image_name = json_file.replace(".json", ".jpg")
        image_path = os.path.join(self.test_folder, image_name)
        json_path = os.path.join(self.test_folder, json_file)
        
        # Load image
        image = Image.open(image_path).convert("RGB")
        
        # Load JSON
        with open(json_path, 'r') as f:
            json_data = json.load(f)
        
        rois = []
        label_ids = []
        
        for i, shape in enumerate(json_data["shapes"]):
            points = shape["points"]
            label_id = f"Blank{i+1}"  # Assign Blank1, Blank2, etc.
            
            x_min = int(min(p[0] for p in points))
            y_min = int(min(p[1] for p in points))
            x_max = int(max(p[0] for p in points))
            y_max = int(max(p[1] for p in points))

            roi = image.crop((x_min, y_min, x_max, y_max))
            if self.transform:
                roi = self.transform(roi)

            rois.append(roi)
            label_ids.append(label_id)

        return rois, label_ids, image_name

def collate_fn_test(batch):
    all_rois = []
    all_label_ids = []
    all_image_ids = []
    
    for rois, label_ids, image_name in batch:
        all_rois.extend(rois)
        all_label_ids.extend(label_ids)
        all_image_ids.extend([image_name] * len(label_ids))
    
    all_rois = torch.stack(all_rois)  # Convert list of ROIs to a tensor
    
    return all_rois, all_image_ids, all_label_ids

# %%
# Define image transformations
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
test_dataset = TestMitosisDataset(test_folder, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn_test)

# %%
predictions = []

with torch.no_grad():
    for rois, image_ids, label_ids in test_loader:
        rois = rois.to(device)
        outputs = vgg19(rois)
        preds = (outputs.sigmoid() > 0.5).long().cpu().numpy()  # Convert to 0 or 1
        
        for img, label, pred in zip(image_ids, label_ids, preds):
            predictions.append([img, label, pred.item()])

# %%
df_pred = pd.DataFrame(predictions, columns=["Image ID", "Label ID", "Prediction"])
df_pred.index += 1  # Row ID starts from 1
df_pred.to_csv("/kaggle/working/mcd_vgg19_predictions6.csv", index_label="Row ID")

# %%
df_pred
# Out:
#              Image ID Label ID  Prediction
# 1     testing0001.jpg   Blank1           1
# 2     testing0001.jpg   Blank2           0
# 3     testing0001.jpg   Blank3           0
# 4     testing0001.jpg   Blank4           0
# 5     testing0001.jpg   Blank5           0
# ...               ...      ...         ...
# 1440  testing0200.jpg   Blank3           0
# 1441  testing0200.jpg   Blank4           0
# 1442  testing0200.jpg   Blank5           0
# 1443  testing0200.jpg   Blank6           0
# 1444  testing0200.jpg   Blank7           0
#
# [1444 rows x 3 columns]

# %%
df_pred['Prediction'].value_counts()
# Out:
# Prediction
# 0    1276
# 1     168
# Name: count, dtype: int64
